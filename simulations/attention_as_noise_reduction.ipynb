# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline


df = pd.read_csv('C:\\Users\\David\\Dropbox\\IDIBAPS\\my code\\Project 1 (master thesis)\\
Modeling angular dimension\\noise_error')

## Codes to run the simulations:
#'C:\\Users\\David\\Dropbox\\IDIBAPS\\my code\\Project 1 (master thesis)\\Modeling angular dimension\\basic_python_attention_noise.ipynb'

# %%
#Realted with noise 
# bias=[]

# sigE= 1.25 #1.5 #  1.5  1--2 (max att, min att)
# sigI= 1.25 #1.5 # 1.6

# for i in range(0,1000):
#     %run "basic_python_attention_noise.ipynb"

# bias_low_attention=bias
# Out:
# Absolute Bias = 1.15
# Absolute Bias = 4.79
# Absolute Bias = 107.72
# Absolute Bias = 0.15
# Absolute Bias = 7.83
# Absolute Bias = 5.69
# Absolute Bias = 8.48
# Absolute Bias = 1.61
# Absolute Bias = 3.11
# Absolute Bias = 5.66
# Absolute Bias = 7.56
# Absolute Bias = 8.16
# Absolute Bias = 5.74
# Absolute Bias = 1.27
# Absolute Bias = 85.24
# Absolute Bias = 10.72
# Absolute Bias = 3.02
# Absolute Bias = 4.5
# Absolute Bias = 6.41
# Absolute Bias = 5.35
# Absolute Bias = 0.11
# Absolute Bias = 57.17
# Absolute Bias = 8.41
# Absolute Bias = 5.52
# Absolute Bias = 2.32
# Absolute Bias = 0.49
# Absolute Bias = 3.43
# Absolute Bias = 1.73
# Absolute Bias = 0.28
# Absolute Bias = 3.6
# Absolute Bias = 0.37
# Absolute Bias = 1.86
# Absolute Bias = 1.91
# Absolute Bias = 6.32
# Absolute Bias = 1.09
# Absolute Bias = 4.71
# Absolute Bias = 3.39
# Absolute Bias = 3.41
# Absolute Bias = 6.32
# Absolute Bias = 0.15
# Absolute Bias = 4.1
# Absolute Bias = 0.61
# Absolute Bias = 3.83
# ...

# %%
# bias=[]

# #Realted with noise
# sigE= 0.5 #1.5 #  1.5  1--2 (max att, min att)
# sigI= 0.5 #1.5 # 1.6

# for i in range(0,1000):
#     %run "basic_python_attention_noise.ipynb"



# bias_high_attention=bias
# Out:
# Absolute Bias = 0.14
# Absolute Bias = 1.63
# Absolute Bias = 1.53
# Absolute Bias = 0.11
# Absolute Bias = 3.09
# Absolute Bias = 0.02
# Absolute Bias = 0.75
# Absolute Bias = 0.34
# Absolute Bias = 3.55
# Absolute Bias = 0.55
# Absolute Bias = 0.3
# Absolute Bias = 1.15
# Absolute Bias = 2.05
# Absolute Bias = 3.79
# Absolute Bias = 0.15
# Absolute Bias = 0.85
# Absolute Bias = 1.06
# Absolute Bias = 1.65
# Absolute Bias = 0.74
# Absolute Bias = 0.24
# Absolute Bias = 0.6
# Absolute Bias = 0.08
# Absolute Bias = 1.04
# Absolute Bias = 0.17
# Absolute Bias = 0.62
# Absolute Bias = 0.03
# Absolute Bias = 0.05
# Absolute Bias = 1.2
# Absolute Bias = 0.35
# Absolute Bias = 1.13
# Absolute Bias = 0.15
# Absolute Bias = 0.09
# Absolute Bias = 1.65
# Absolute Bias = 3.31
# Absolute Bias = 0.06
# Absolute Bias = 4.37
# Absolute Bias = 0.19
# Absolute Bias = 1.29
# Absolute Bias = 0.27
# Absolute Bias = 3.9
# Absolute Bias = 0.04
# Absolute Bias = 1.04
# Absolute Bias = 0.44
# ...

# %%
# a = pd.DataFrame({'absolute bias':bias_high_attention, 'noise':'high'})
# b= pd.DataFrame({'absolute bias':bias_low_attention, 'noise':'low'})


# def remove_outlier(df_in, col_name):
#     q1 = df_in[col_name].quantile(0.25)
#     q3 = df_in[col_name].quantile(0.75)
#     iqr = q3-q1 #Interquartile range
#     fence_low  = q1-1.5*iqr
#     fence_high = q3+1.5*iqr
#     df_out = df_in.loc[(df_in[col_name] > fence_low) & (df_in[col_name] < fence_high)]
#     return df_out

# b_outliers = remove_outlier(b, 'absolute bias')

# ####
# df_raw= pd.concat([a,b])
# df= pd.concat([a,b_outliers])


#df_raw.to_csv('noise_error_raw')
#df.to_csv('noise_error')

# %%
sns.barplot(x='noise', y='absolute bias', data=df)
sns.set_style('white')
plt.title('Noise reduction as attention')
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().get_xaxis().tick_bottom()
plt.gca().get_yaxis().tick_left()
# Out:
# C:\Users\David\Anaconda3\envs\python3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
