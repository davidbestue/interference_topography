# %%
from model_radial2 import *
# %load_ext autoreload
# %autoreload 2

# %%
err =model(totalTime=2000, 
           targ_onset=100,  
           presentation_period=350,
           positions=60, 
           tauE=9, tauI=4,  n_stims=1, 
           I0E=0.1, I0I=0.5,
           GEE=0.025, GEI=0.02, GIE=0.01 , GII=0.1, 
           sigE=0.8, sigI=1.6, 
           #sigE=0., sigI=0., 
           kappa_E=100, kappa_I=20, 
           kappa_stim=100, N=512,
           plot_connectivity=True, 
           plot_rate=False, plot_hm=False, 
           plot_fit=False, save_RE=True)

print(err[0])



simulation_heatmap_R(RE=err[2], time_simulation=2000, position=60, target_onset=100, pres_period=350)
# Out:
# -0.9225982832670354

# %%
err =model(totalTime=3000, 
           targ_onset=100,  
           presentation_period=350,
           positions=300, 
           tauE=9, tauI=4,  n_stims=1, 
           I0E=0.1, I0I=0.5,
           GEE=0.025, GEI=0.02, GIE=0.01 , GII=0.1, 
           sigE=0.8, sigI=1.6, 
           #sigE=0., sigI=0., 
           kappa_E=100, kappa_I=20, 
           kappa_stim=100, N=512,
           plot_connectivity=False, 
           plot_rate=False, plot_hm=False, 
           plot_fit=False, save_RE=True)

print(err[0])


simulation_heatmap_R(RE=err[2], time_simulation=3000, position=300, target_onset=100, pres_period=350)
# Out:
# 10.299872689703989

# %%
err =model(totalTime=2000, 
           targ_onset=100,  
           presentation_period=350,
           positions=60, 
           tauE=9, tauI=4,  n_stims=1, 
           I0E=0.1, I0I=0.5,
           GEE=0.025, GEI=0.02, GIE=0.01 , GII=0.1, 
           sigE=0.8, sigI=1.6, 
           #sigE=0., sigI=0., 
           kappa_E=100, kappa_I=20, 
           kappa_stim=100, N=512,
           plot_connectivity=True, 
           plot_rate=False, plot_hm=False, 
           plot_fit=False, save_RE=True)

print(err[0])



simulation_heatmap_R(RE=err[2], time_simulation=2000, position=60, target_onset=100, pres_period=350)


err =model(totalTime=3000, 
           targ_onset=100,  
           presentation_period=350,
           positions=300, 
           tauE=9, tauI=4,  n_stims=1, 
           I0E=0.1, I0I=0.5,
           GEE=0.025, GEI=0.02, GIE=0.01 , GII=0.1, 
           sigE=0.8, sigI=1.6, 
           #sigE=0., sigI=0., 
           kappa_E=100, kappa_I=20, 
           kappa_stim=100, N=512,
           plot_connectivity=False, 
           plot_rate=False, plot_hm=False, 
           plot_fit=False, save_RE=True)

print(err[0])


simulation_heatmap_R(RE=err[2], time_simulation=3000, position=300, target_onset=100, pres_period=350)
# Out:
# 4.877240296609003
# 13.809721737111886

# %%
err =model(totalTime=3000, 
           targ_onset=100,  
           presentation_period=350,
           positions=350, 
           tauE=9, tauI=4,  n_stims=1, 
           I0E=0.1, I0I=0.5,
           GEE=0.025, GEI=0.02, GIE=0.01 , GII=0.1, 
           sigE=0.8, sigI=1.6, 
           #sigE=0., sigI=0., 
           kappa_E=100, kappa_I=20, 
           kappa_stim=100, N=512,
           plot_connectivity=False, 
           plot_rate=False, plot_hm=False, 
           plot_fit=False, save_RE=True)

print(err[0])


simulation_heatmap_R(RE=err[2], time_simulation=3000, position=300, target_onset=100, pres_period=350)
# Out:
# 6.748357033574962
