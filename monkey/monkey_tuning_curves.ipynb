# %%
#Libraries
from math import floor, exp, sqrt, pi
import cmath
import numpy
from numpy import e, cos, zeros, arange, roll, where, random, ones, mean, reshape, dot, array, flipud, pi, exp, dot, angle, degrees, shape, linspace
import matplotlib.pyplot as plt
from itertools import chain
import scipy
from scipy import special
import seaborn as sns
import pandas as pd
import seaborn
import statsmodels.formula.api as smf
from scikits.bootstrap import ci 
from scipy.stats import sem, norm, zscore

# %%
s = numpy.load('C:\\Users\\David\\Dropbox\\IDIBAPS\\3rings_ODR_christos\\std_circ_rad.npy', encoding='latin1' )
import numpy as np
np.shape(s)
values=  [np.mean(s[i]) for i in range(len(s))]
values
# Out:
# [1.7972270003725304, 1.8760000347856003, 2.0627727100120303]

# %%
#in analysis_ind_neurons --> numpy.save('std_circ_rad.npy', s)

#s = numpy.load('/home/david/Dropbox/IDIBAPS/3rings_ODR_christos/std_circ_rad.npy')


#values=  map(mean, s)
cis=[ci(s[i], statfunction=numpy.mean) for i in range(0, len(s))]
cis=array(cis)
sems=[sem(s[i]) for i in range(0, len(s))]
sems=[[values[i]-sems[i], values[i]+sems[i]] for i in range(0, len(s))]
sems = array(sems)


plt.figure()
plt.style.use('default')
plt.plot(values, marker='o', color='k')
plt.fill_between(range(3),sems[:,0],sems[:,1],color="cyan",label="ring 1",alpha=0.3)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.gca().get_xaxis().tick_bottom()
plt.gca().get_yaxis().tick_left()
plt.xticks([0,1,2])
plt.xticks([0,1,2],['r1', 'r2', 'r3'])
plt.ylabel('Std. of tuning curves')
plt.title('Neuronal tuning curve with eccentricity')
plt.show(block=False)

# %%
colors=["cyan", "magenta"]
Lbls=['r1', 'r3']


plt.figure()
plt.style.use('default')

for idx, V in enumerate([values[0], values[2]]):
    # Fit a normal distribution to the data:
    #mu, std = norm.fit(data)
    mu=0
    std=V
    print(std)    
    # Plot the PDF.
    xmin, xmax = [-8, 8]
    x = np.linspace(xmin, xmax, 1000)
    p = norm.pdf(x, mu, std)
    plt.plot(x, p, colors[idx], linewidth=2, label=Lbls[idx])
    #
    
    


plt.legend()
#plt.title("Expected tuning curves" )
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['top'].set_visible(False)
plt.xticks([0],['Prefered'])
plt.show(block=False)
# Out:
# 1.7972270003725304
# 2.0627727100120303
